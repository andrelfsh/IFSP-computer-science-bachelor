# %% [markdown]
# Este exemplo busca investigar a relação entre satisfação pessoal e bem-estar por país (medida pelo índice Better Life Index) e a renda, isto é, o Produto Interno Bruto de um país (medido pelo Gross Domestic Product per capta).
#
# https://docs.google.com/presentation/d/1WmDzZCqD16PHhwROKy7Wf5YkZ5hiNwlh/edit?slide=id.p1#slide=id.p1
#
# *   Um país rico possui apresenta maior bem-estar pessoal?
#
#
#
# Links <br>
# CSV - Better Life Index <br>
# 2023 - https://stats.oecd.org/index.aspx?DataSetCode=BLI <br>
# CSV - GDP Per Capta<br>
# Atual - https://data.worldbank.org/indicator/NY.GDP.PCAP.CD?most_recent_value_desc=true <br>
# 2018 - https://www.kaggle.com/datasets/nitishabharathi/gdp-per-capita-all-countries?resource=download

# %% [markdown]
# # Pandas
# * Pandas is a Python library used for working with data sets.
# * It has functions for analyzing, cleaning, exploring, and manipulating big amounts of data.
#  * Is there a correlation between two or more columns?
#  * What is average value?
#  * Max value?
#  * Min value?
#
# **DataFrame**
#
# * A data frame is a structured representation of data.

# %%
import pandas as pd

df_BLI = pd.read_csv('OECD,DF_BLI,+all.csv', sep = ",") # data frame = representacao estruturada do dado. usa pandas para ler
df_BLI # exibe conteúdo do data frame (apenas no notebook do google)
# Out:
#      STRUCTURE      STRUCTURE_ID     STRUCTURE_NAME ACTION LOCATION  \
# 0     DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      AUT
# 1     DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      BEL
# 2     DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CAN
# 3     DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CZE
# 4     DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      DNK
# ...        ...               ...                ...    ...      ...
# 2364  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CRI
# 2365  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CRI
# 2366  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CRI
# 2367  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CRI
# 2368  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CRI
#
#          Country INDICATOR                 Indicator MEASURE Measure  ...  \
# 0        Austria   JE_LMIS  Labour market insecurity       L   Value  ...
# 1        Belgium   JE_LMIS  Labour market insecurity       L   Value  ...
# 2         Canada   JE_LMIS  Labour market insecurity       L   Value  ...
# 3        Czechia   JE_LMIS  Labour market insecurity       L   Value  ...
# 4        Denmark   JE_LMIS  Labour market insecurity       L   Value  ...
# ...          ...       ...                       ...     ...     ...  ...
# 2364  Costa Rica    HS_LEB           Life expectancy       L   Value  ...
# 2365  Costa Rica    HS_LEB           Life expectancy       L   Value  ...
# 2366  Costa Rica   PS_REPH             Homicide rate       L   Value  ...
# 2367  Costa Rica   PS_REPH             Homicide rate       L   Value  ...
# 2368  Costa Rica   PS_REPH             Homicide rate       L   Value  ...
#
#      OBS_VALUE  Observation Value  OBS_STATUS  Observation Status  \
# 0          2.3                NaN           A                 NaN
# 1          2.4                NaN           A                 NaN
# 2          3.8                NaN           A                 NaN
# 3          2.3                NaN           A                 NaN
# 4          4.5                NaN           A                 NaN
# ...        ...                ...         ...                 ...
# 2364      77.9                NaN           A                 NaN
# 2365      83.0                NaN           A                 NaN
# 2366      10.0                NaN           A                 NaN
# 2367      18.2                NaN           A                 NaN
# 2368       1.8                NaN           A                 NaN
#
#      UNIT_MEASURE  Unit of Measures UNIT_MULT Multiplier  BASE_PER  \
# 0              PC        Percentage         0      Units       NaN
# 1              PC        Percentage         0      Units       NaN
# 2              PC        Percentage         0      Units       NaN
# 3              PC        Percentage         0      Units       NaN
# 4              PC        Percentage         0      Units       NaN
# ...           ...               ...       ...        ...       ...
# 2364           YR             Years         0      Units       NaN
# 2365           YR             Years         0      Units       NaN
# 2366        RATIO             Ratio         0      Units       NaN
# 2367        RATIO             Ratio         0      Units       NaN
# 2368        RATIO             Ratio         0      Units       NaN
#
#      Base reference period
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 2364                   NaN
# 2365                   NaN
# 2366                   NaN
# 2367                   NaN
# 2368                   NaN
#
# [2369 rows x 22 columns]

# %%
df_BLI.head() # visualiza as 5 primeiras linhas de df_BLI
# Out:
#   STRUCTURE      STRUCTURE_ID     STRUCTURE_NAME ACTION LOCATION  Country  \
# 0  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      AUT  Austria
# 1  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      BEL  Belgium
# 2  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CAN   Canada
# 3  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CZE  Czechia
# 4  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      DNK  Denmark
#
#   INDICATOR                 Indicator MEASURE Measure  ... OBS_VALUE  \
# 0   JE_LMIS  Labour market insecurity       L   Value  ...       2.3
# 1   JE_LMIS  Labour market insecurity       L   Value  ...       2.4
# 2   JE_LMIS  Labour market insecurity       L   Value  ...       3.8
# 3   JE_LMIS  Labour market insecurity       L   Value  ...       2.3
# 4   JE_LMIS  Labour market insecurity       L   Value  ...       4.5
#
#    Observation Value  OBS_STATUS  Observation Status UNIT_MEASURE  \
# 0                NaN           A                 NaN           PC
# 1                NaN           A                 NaN           PC
# 2                NaN           A                 NaN           PC
# 3                NaN           A                 NaN           PC
# 4                NaN           A                 NaN           PC
#
#    Unit of Measures UNIT_MULT Multiplier  BASE_PER Base reference period
# 0        Percentage         0      Units       NaN                   NaN
# 1        Percentage         0      Units       NaN                   NaN
# 2        Percentage         0      Units       NaN                   NaN
# 3        Percentage         0      Units       NaN                   NaN
# 4        Percentage         0      Units       NaN                   NaN
#
# [5 rows x 22 columns]

# %%
df_BLI["INEQUALITY"].value_counts() # conta quantas vezes cada valor aparece na coluna inequality (nn aparece acima)
# Out:
# INEQUALITY
# TOT    935
# WMN    558
# MN     558
# LW     159
# HGH    159
# Name: count, dtype: int64

# %%
df_BLI.columns # mostra colunas (agora aparece o inequality)
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'LOCATION',
#        'Country', 'INDICATOR', 'Indicator', 'MEASURE', 'Measure', 'INEQUALITY',
#        'Inequality', 'OBS_VALUE', 'Observation Value', 'OBS_STATUS',
#        'Observation Status', 'UNIT_MEASURE', 'Unit of Measures', 'UNIT_MULT',
#        'Multiplier', 'BASE_PER', 'Base reference period'],
#       dtype='object')

# %%
df_BLI.describe() # resumo estatístico
# Out:
#        Inequality      OBS_VALUE  Observation Value  Observation Status  \
# count         0.0    2369.000000                0.0                 0.0
# mean          NaN    5299.220612                NaN                 NaN
# std           NaN   41894.336828                NaN                 NaN
# min           NaN       0.000000                NaN                 NaN
# 25%           NaN       7.100000                NaN                 NaN
# 50%           NaN      66.000000                NaN                 NaN
# 75%           NaN      88.000000                NaN                 NaN
# max           NaN  941162.000000                NaN                 NaN
#
#        UNIT_MULT  BASE_PER  Base reference period
# count     2369.0       0.0                    0.0
# mean         0.0       NaN                    NaN
# std          0.0       NaN                    NaN
# min          0.0       NaN                    NaN
# 25%          0.0       NaN                    NaN
# 50%          0.0       NaN                    NaN
# 75%          0.0       NaN                    NaN
# max          0.0       NaN                    NaN

# %%
df_BLI.info() # resumo estrutural
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2369 entries, 0 to 2368
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   STRUCTURE              2369 non-null   object
#  1   STRUCTURE_ID           2369 non-null   object
#  2   STRUCTURE_NAME         2369 non-null   object
#  3   ACTION                 2369 non-null   object
#  4   LOCATION               2369 non-null   object
#  5   Country                2369 non-null   object
#  6   INDICATOR              2369 non-null   object
#  7   Indicator              2369 non-null   object
#  8   MEASURE                2369 non-null   object
#  9   Measure                2369 non-null   object
#  10  INEQUALITY             2369 non-null   object
#  11  Inequality             0 non-null      float64
#  12  OBS_VALUE              2369 non-null   float64
#  13  Observation Value      0 non-null      float64
#  14  OBS_STATUS             2369 non-null   object
#  15  Observation Status     0 non-null      float64
#  16  UNIT_MEASURE           2369 non-null   object
#  17  Unit of Measures       2369 non-null   object
#  18  UNIT_MULT              2369 non-null   int64
#  19  Multiplier             2369 non-null   object
#  20  BASE_PER               0 non-null      float64
#  21  Base reference period  0 non-null      float64
# dtypes: float64(6), int64(1), object(15)
# memory usage: 407.3+ KB

# %%
# Filtrando (Where)
# Necessário conhecimento do domínio
df_BLI = df_BLI [ df_BLI['INEQUALITY'] == 'TOT'] # apenas linhas que coluna INEQUALITY tem TOT
df_BLI = df_BLI [ df_BLI['Indicator'] == 'Life satisfaction' ] #  "  "
df_BLI
# Out:
#      STRUCTURE      STRUCTURE_ID     STRUCTURE_NAME ACTION LOCATION  \
# 1519  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      AUS
# 1520  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      AUT
# 1521  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      BEL
# 1522  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CAN
# 1523  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CZE
# 1524  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      DNK
# 1525  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      FIN
# 1526  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      FRA
# 1527  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      DEU
# 1528  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      GRC
# 1529  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      HUN
# 1530  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      ISL
# 1531  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      IRL
# 1532  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      ITA
# 1533  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      JPN
# 1534  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      KOR
# 1535  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      LUX
# 1536  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      MEX
# 1537  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      NLD
# 1538  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      NZL
# 1539  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      NOR
# 1540  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      POL
# 1541  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      PRT
# 1542  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      SVK
# 1543  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      ESP
# 1544  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      SWE
# 1545  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CHE
# 1546  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      TUR
# 1547  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      GBR
# 1548  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      USA
# 1549  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      BRA
# 1550  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CHL
# 1551  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      EST
# 1552  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      ISR
# 1553  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      LVA
# 1554  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      RUS
# 1555  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      SVN
# 1556  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      ZAF
# 1557  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I     OECD
# 1724  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      COL
# 1725  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      LTU
# 1740  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CRI
#
#               Country INDICATOR          Indicator MEASURE Measure  ...  \
# 1519        Australia   SW_LIFS  Life satisfaction       L   Value  ...
# 1520          Austria   SW_LIFS  Life satisfaction       L   Value  ...
# 1521          Belgium   SW_LIFS  Life satisfaction       L   Value  ...
# 1522           Canada   SW_LIFS  Life satisfaction       L   Value  ...
# 1523          Czechia   SW_LIFS  Life satisfaction       L   Value  ...
# 1524          Denmark   SW_LIFS  Life satisfaction       L   Value  ...
# 1525          Finland   SW_LIFS  Life satisfaction       L   Value  ...
# 1526           France   SW_LIFS  Life satisfaction       L   Value  ...
# 1527          Germany   SW_LIFS  Life satisfaction       L   Value  ...
# 1528           Greece   SW_LIFS  Life satisfaction       L   Value  ...
# 1529          Hungary   SW_LIFS  Life satisfaction       L   Value  ...
# 1530          Iceland   SW_LIFS  Life satisfaction       L   Value  ...
# 1531          Ireland   SW_LIFS  Life satisfaction       L   Value  ...
# 1532            Italy   SW_LIFS  Life satisfaction       L   Value  ...
# 1533            Japan   SW_LIFS  Life satisfaction       L   Value  ...
# 1534            Korea   SW_LIFS  Life satisfaction       L   Value  ...
# 1535       Luxembourg   SW_LIFS  Life satisfaction       L   Value  ...
# 1536           Mexico   SW_LIFS  Life satisfaction       L   Value  ...
# 1537      Netherlands   SW_LIFS  Life satisfaction       L   Value  ...
# 1538      New Zealand   SW_LIFS  Life satisfaction       L   Value  ...
# 1539           Norway   SW_LIFS  Life satisfaction       L   Value  ...
# 1540           Poland   SW_LIFS  Life satisfaction       L   Value  ...
# 1541         Portugal   SW_LIFS  Life satisfaction       L   Value  ...
# 1542  Slovak Republic   SW_LIFS  Life satisfaction       L   Value  ...
# 1543            Spain   SW_LIFS  Life satisfaction       L   Value  ...
# 1544           Sweden   SW_LIFS  Life satisfaction       L   Value  ...
# 1545      Switzerland   SW_LIFS  Life satisfaction       L   Value  ...
# 1546          Türkiye   SW_LIFS  Life satisfaction       L   Value  ...
# 1547   United Kingdom   SW_LIFS  Life satisfaction       L   Value  ...
# 1548    United States   SW_LIFS  Life satisfaction       L   Value  ...
# 1549           Brazil   SW_LIFS  Life satisfaction       L   Value  ...
# 1550            Chile   SW_LIFS  Life satisfaction       L   Value  ...
# 1551          Estonia   SW_LIFS  Life satisfaction       L   Value  ...
# 1552           Israel   SW_LIFS  Life satisfaction       L   Value  ...
# 1553           Latvia   SW_LIFS  Life satisfaction       L   Value  ...
# 1554           Russia   SW_LIFS  Life satisfaction       L   Value  ...
# 1555         Slovenia   SW_LIFS  Life satisfaction       L   Value  ...
# 1556     South Africa   SW_LIFS  Life satisfaction       L   Value  ...
# 1557     OECD - Total   SW_LIFS  Life satisfaction       L   Value  ...
# 1724         Colombia   SW_LIFS  Life satisfaction       L   Value  ...
# 1725        Lithuania   SW_LIFS  Life satisfaction       L   Value  ...
# 1740       Costa Rica   SW_LIFS  Life satisfaction       L   Value  ...
#
#      OBS_VALUE  Observation Value  OBS_STATUS  Observation Status  \
# 1519       7.1                NaN           A                 NaN
# 1520       7.2                NaN           A                 NaN
# 1521       6.8                NaN           A                 NaN
# 1522       7.0                NaN           A                 NaN
# 1523       6.9                NaN           A                 NaN
# 1524       7.5                NaN           A                 NaN
# 1525       7.9                NaN           A                 NaN
# 1526       6.7                NaN           A                 NaN
# 1527       7.3                NaN           A                 NaN
# 1528       5.8                NaN           A                 NaN
# 1529       6.0                NaN           A                 NaN
# 1530       7.6                NaN           A                 NaN
# 1531       7.0                NaN           A                 NaN
# 1532       6.5                NaN           A                 NaN
# 1533       6.1                NaN           A                 NaN
# 1534       5.8                NaN           A                 NaN
# 1535       7.4                NaN           A                 NaN
# 1536       6.0                NaN           A                 NaN
# 1537       7.5                NaN           A                 NaN
# 1538       7.3                NaN           A                 NaN
# 1539       7.3                NaN           A                 NaN
# 1540       6.1                NaN           A                 NaN
# 1541       5.8                NaN           A                 NaN
# 1542       6.5                NaN           A                 NaN
# 1543       6.5                NaN           A                 NaN
# 1544       7.3                NaN           A                 NaN
# 1545       7.5                NaN           A                 NaN
# 1546       4.9                NaN           A                 NaN
# 1547       6.8                NaN           A                 NaN
# 1548       7.0                NaN           A                 NaN
# 1549       6.1                NaN           A                 NaN
# 1550       6.2                NaN           A                 NaN
# 1551       6.5                NaN           A                 NaN
# 1552       7.2                NaN           A                 NaN
# 1553       6.2                NaN           A                 NaN
# 1554       5.5                NaN           A                 NaN
# 1555       6.5                NaN           A                 NaN
# 1556       4.9                NaN           A                 NaN
# 1557       6.7                NaN           A                 NaN
# 1724       5.7                NaN           A                 NaN
# 1725       6.4                NaN           A                 NaN
# 1740       6.3                NaN           A                 NaN
#
#      UNIT_MEASURE  Unit of Measures UNIT_MULT Multiplier  BASE_PER  \
# 1519      AVSCORE     Average score         0      Units       NaN
# 1520      AVSCORE     Average score         0      Units       NaN
# 1521      AVSCORE     Average score         0      Units       NaN
# 1522      AVSCORE     Average score         0      Units       NaN
# 1523      AVSCORE     Average score         0      Units       NaN
# 1524      AVSCORE     Average score         0      Units       NaN
# 1525      AVSCORE     Average score         0      Units       NaN
# 1526      AVSCORE     Average score         0      Units       NaN
# 1527      AVSCORE     Average score         0      Units       NaN
# 1528      AVSCORE     Average score         0      Units       NaN
# 1529      AVSCORE     Average score         0      Units       NaN
# 1530      AVSCORE     Average score         0      Units       NaN
# 1531      AVSCORE     Average score         0      Units       NaN
# 1532      AVSCORE     Average score         0      Units       NaN
# 1533      AVSCORE     Average score         0      Units       NaN
# 1534      AVSCORE     Average score         0      Units       NaN
# 1535      AVSCORE     Average score         0      Units       NaN
# 1536      AVSCORE     Average score         0      Units       NaN
# 1537      AVSCORE     Average score         0      Units       NaN
# 1538      AVSCORE     Average score         0      Units       NaN
# 1539      AVSCORE     Average score         0      Units       NaN
# 1540      AVSCORE     Average score         0      Units       NaN
# 1541      AVSCORE     Average score         0      Units       NaN
# 1542      AVSCORE     Average score         0      Units       NaN
# 1543      AVSCORE     Average score         0      Units       NaN
# 1544      AVSCORE     Average score         0      Units       NaN
# 1545      AVSCORE     Average score         0      Units       NaN
# 1546      AVSCORE     Average score         0      Units       NaN
# 1547      AVSCORE     Average score         0      Units       NaN
# 1548      AVSCORE     Average score         0      Units       NaN
# 1549      AVSCORE     Average score         0      Units       NaN
# 1550      AVSCORE     Average score         0      Units       NaN
# 1551      AVSCORE     Average score         0      Units       NaN
# 1552      AVSCORE     Average score         0      Units       NaN
# 1553      AVSCORE     Average score         0      Units       NaN
# 1554      AVSCORE     Average score         0      Units       NaN
# 1555      AVSCORE     Average score         0      Units       NaN
# 1556      AVSCORE     Average score         0      Units       NaN
# 1557      AVSCORE     Average score         0      Units       NaN
# 1724      AVSCORE     Average score         0      Units       NaN
# 1725      AVSCORE     Average score         0      Units       NaN
# 1740      AVSCORE     Average score         0      Units       NaN
#
#      Base reference period
# 1519                   NaN
# 1520                   NaN
# 1521                   NaN
# 1522                   NaN
# 1523                   NaN
# 1524                   NaN
# 1525                   NaN
# 1526                   NaN
# 1527                   NaN
# 1528                   NaN
# 1529                   NaN
# 1530                   NaN
# 1531                   NaN
# 1532                   NaN
# 1533                   NaN
# 1534                   NaN
# 1535                   NaN
# 1536                   NaN
# 1537                   NaN
# 1538                   NaN
# 1539                   NaN
# 1540                   NaN
# 1541                   NaN
# 1542                   NaN
# 1543                   NaN
# 1544                   NaN
# 1545                   NaN
# 1546                   NaN
# 1547                   NaN
# 1548                   NaN
# 1549                   NaN
# 1550                   NaN
# 1551                   NaN
# 1552                   NaN
# 1553                   NaN
# 1554                   NaN
# 1555                   NaN
# 1556                   NaN
# 1557                   NaN
# 1724                   NaN
# 1725                   NaN
# 1740                   NaN
#
# [42 rows x 22 columns]

# %%
df_BLI = df_BLI[['LOCATION','Country','OBS_VALUE']] # Seleciona apenas 3 colunas do DataFrame
df_BLI
# Out:
#      LOCATION          Country  OBS_VALUE
# 1525      FIN          Finland        7.9
# 1530      ISL          Iceland        7.6
# 1537      NLD      Netherlands        7.5
# 1545      CHE      Switzerland        7.5
# 1524      DNK          Denmark        7.5
# 1535      LUX       Luxembourg        7.4
# 1527      DEU          Germany        7.3
# 1538      NZL      New Zealand        7.3
# 1539      NOR           Norway        7.3
# 1544      SWE           Sweden        7.3
# 1520      AUT          Austria        7.2
# 1552      ISR           Israel        7.2
# 1519      AUS        Australia        7.1
# 1531      IRL          Ireland        7.0
# 1522      CAN           Canada        7.0
# 1548      USA    United States        7.0
# 1523      CZE          Czechia        6.9
# 1521      BEL          Belgium        6.8
# 1547      GBR   United Kingdom        6.8
# 1526      FRA           France        6.7
# 1557     OECD     OECD - Total        6.7
# 1555      SVN         Slovenia        6.5
# 1543      ESP            Spain        6.5
# 1542      SVK  Slovak Republic        6.5
# 1551      EST          Estonia        6.5
# 1532      ITA            Italy        6.5
# 1725      LTU        Lithuania        6.4
# 1740      CRI       Costa Rica        6.3
# 1550      CHL            Chile        6.2
# 1553      LVA           Latvia        6.2
# 1533      JPN            Japan        6.1
# 1540      POL           Poland        6.1
# 1549      BRA           Brazil        6.1
# 1536      MEX           Mexico        6.0
# 1529      HUN          Hungary        6.0
# 1528      GRC           Greece        5.8
# 1541      PRT         Portugal        5.8
# 1534      KOR            Korea        5.8
# 1724      COL         Colombia        5.7
# 1554      RUS           Russia        5.5
# 1546      TUR          Türkiye        4.9
# 1556      ZAF     South Africa        4.9

# %%
df_BLI.describe() # estatistico
# Out:
#        OBS_VALUE
# count  42.000000
# mean    6.602381
# std     0.716526
# min     4.900000
# 25%     6.100000
# 50%     6.600000
# 75%     7.200000
# max     7.900000

# %%
df_BLI.sort_values("OBS_VALUE",ascending=False, inplace = True) # ordena df por obs_value. decrescente. altera o df original (nn faz copia)
df_BLI
# Out:
# <ipython-input-17-79c5eeb1dbe7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_BLI.sort_values("OBS_VALUE",ascending=False, inplace = True) # ordena df por obs_value. decrescente. altera o df original (nn faz copia)
#      LOCATION          Country  OBS_VALUE
# 1525      FIN          Finland        7.9
# 1530      ISL          Iceland        7.6
# 1537      NLD      Netherlands        7.5
# 1545      CHE      Switzerland        7.5
# 1524      DNK          Denmark        7.5
# 1535      LUX       Luxembourg        7.4
# 1527      DEU          Germany        7.3
# 1538      NZL      New Zealand        7.3
# 1539      NOR           Norway        7.3
# 1544      SWE           Sweden        7.3
# 1520      AUT          Austria        7.2
# 1552      ISR           Israel        7.2
# 1519      AUS        Australia        7.1
# 1531      IRL          Ireland        7.0
# 1522      CAN           Canada        7.0
# 1548      USA    United States        7.0
# 1523      CZE          Czechia        6.9
# 1521      BEL          Belgium        6.8
# 1547      GBR   United Kingdom        6.8
# 1526      FRA           France        6.7
# 1557     OECD     OECD - Total        6.7
# 1555      SVN         Slovenia        6.5
# 1543      ESP            Spain        6.5
# 1542      SVK  Slovak Republic        6.5
# 1551      EST          Estonia        6.5
# 1532      ITA            Italy        6.5
# 1725      LTU        Lithuania        6.4
# 1740      CRI       Costa Rica        6.3
# 1550      CHL            Chile        6.2
# 1553      LVA           Latvia        6.2
# 1533      JPN            Japan        6.1
# 1540      POL           Poland        6.1
# 1549      BRA           Brazil        6.1
# 1536      MEX           Mexico        6.0
# 1529      HUN          Hungary        6.0
# 1528      GRC           Greece        5.8
# 1541      PRT         Portugal        5.8
# 1534      KOR            Korea        5.8
# 1724      COL         Colombia        5.7
# 1554      RUS           Russia        5.5
# 1546      TUR          Türkiye        4.9
# 1556      ZAF     South Africa        4.9

# %%
#GDP Per Capta
#https://data.worldbank.org/indicator/NY.GDP.PCAP.CD?most_recent_value_desc=true -- 14/03/2023
#https://www.kaggle.com/datasets/nitishabharathi/gdp-per-capita-all-countries?resource=download

df_GDP = pd.read_csv("GDP.csv", sep = ",")
df_GDP
# Out:
#          Country  Country Code          1990          1991          1992  \
# 0           Aruba          ABW  24101.109430  25870.755940  26533.343900
# 1     Afghanistan          AFG           NaN           NaN           NaN
# 2          Angola          AGO   3089.683369   3120.356148   2908.160798
# 3         Albania          ALB   2549.473022   1909.114038   1823.307673
# 4      Arab World          ARB   6808.206995   6872.273195   7255.328362
# ..            ...          ...           ...           ...           ...
# 255        Kosovo          XKX           NaN           NaN           NaN
# 256   Yemen, Rep.          YEM   2223.028771   2325.263661   2443.920401
# 257  South Africa          ZAF   6424.502215   6414.057923   6261.716184
# 258        Zambia          ZMB   1517.926292   1528.781247   1499.340446
# 259      Zimbabwe          ZWE   1829.677575   1949.732966   1777.843425
#
#              1993          1994          1995          1996          1997  \
# 0    27430.752400  28656.520210  28648.990020  28499.089430  30215.949230
# 1             NaN           NaN           NaN           NaN           NaN
# 2     2190.768160   2195.532289   2496.199493   2794.896906   2953.342709
# 3     2057.449657   2289.873135   2665.764906   2980.066288   2717.362124
# 4     7458.647059   7645.682856   7774.207360   8094.149842   8397.515692
# ..            ...           ...           ...           ...           ...
# 255           NaN           NaN           NaN           NaN           NaN
# 256   2472.188808   2569.648739   2657.813447   2730.145147   2829.866193
# 257   6331.777580   6520.866604   6719.583315   7000.801619   7179.806651
# 258   1600.347799   1457.627696   1493.123972   1572.973238   1616.492883
# 259   1807.225700   1986.028160   2004.362417   2227.060619   2303.829588
#
#      ...          2010          2011          2012          2013  \
# 0    ...  33732.847450  35492.618490  35498.982090  37419.892820
# 1    ...   1637.377987   1626.764793   1806.763930   1874.765634
# 2    ...   6230.297028   6346.395122   6772.528333   6980.423038
# 3    ...   9628.025783  10207.752350  10526.235450  10571.010650
# 4    ...  14127.778020  14518.827450  15423.465390  15824.780110
# ..   ...           ...           ...           ...           ...
# 255  ...   7782.875107   8222.285712   8547.652384   8903.763429
# 256  ...   4472.726448   3876.302619   3935.167105   4084.882967
# 257  ...  11728.160490  12179.174190  12488.215570  12815.727070
# 258  ...   3269.794329   3419.010460   3634.780353   3765.584162
# 259  ...   1888.566739   2168.110293   2534.541919   2583.985638
#
#              2014          2015          2016          2017          2018  \
# 0    38223.372260  38249.054870  38390.271650  39454.629830           NaN
# 1     1897.525938   1886.692977   1896.992520   1934.636754   1955.006208
# 2     7199.245478   7096.600615   6756.935074   6650.584940   6452.355165
# 3    11259.225890  11662.030480  11868.178970  12930.140030  13364.155400
# 4    16153.244860  16501.792590  16935.383300  17099.889390  17570.137600
# ..            ...           ...           ...           ...           ...
# 255   9194.741819   9781.019679  10208.857900  10756.663460  11348.363450
# 256   4045.500031   3320.110156   2827.691023   2645.308383   2575.126385
# 257  13090.476830  13185.253280  13188.029620  13438.282890  13686.882360
# 258   3893.549478   3927.761816   3998.004435   4090.120040   4223.906936
# 259   2648.568967   2679.580317   2687.385429   2825.725122   3029.793005
#
#      2019
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 255   NaN
# 256   NaN
# 257   NaN
# 258   NaN
# 259   NaN
#
# [260 rows x 32 columns]

# %%
df_GDP.columns
# Out:
# Index(['Country ', 'Country Code', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
df_GDP = df_GDP[['Country Code','Country ','2018']] # cria df só com esses columns
df_GDP
# Out:
#     Country Code      Country           2018
# 0            ABW         Aruba           NaN
# 1            AFG   Afghanistan   1955.006208
# 2            AGO        Angola   6452.355165
# 3            ALB       Albania  13364.155400
# 4            ARB    Arab World  17570.137600
# ..           ...           ...           ...
# 255          XKX        Kosovo  11348.363450
# 256          YEM   Yemen, Rep.   2575.126385
# 257          ZAF  South Africa  13686.882360
# 258          ZMB        Zambia   4223.906936
# 259          ZWE      Zimbabwe   3029.793005
#
# [260 rows x 3 columns]

# %%
df_GDP.describe() # estatistico
# Out:
#                 2018
# count     231.000000
# mean    21134.599621
# std     21946.871195
# min       744.182072
# 25%      4953.221142
# 50%     14623.674050
# 75%     29899.971315
# max    126898.425900

# %%
df_GDP.info() # estrutural
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  260 non-null    object
#  1   Country       260 non-null    object
#  2   2018          231 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 6.2+ KB

# %%
#Junção de ambos DFs por código de páis
df = df_BLI.set_index('LOCATION').join(df_GDP.set_index('Country Code'), how = 'inner') # intersecção (aparece em ambos)
df
# Out:
#              Country  OBS_VALUE            Country           2018
# FIN          Finland        7.9             Finland   48416.93603
# ISL          Iceland        7.6             Iceland   57303.06078
# NLD      Netherlands        7.5         Netherlands   56328.94114
# CHE      Switzerland        7.5         Switzerland   68060.94105
# DNK          Denmark        7.5             Denmark   55671.16527
# LUX       Luxembourg        7.4          Luxembourg  113337.42050
# DEU          Germany        7.3             Germany   53074.54012
# NZL      New Zealand        7.3         New Zealand   41005.42087
# NOR           Norway        7.3              Norway   65510.58527
# SWE           Sweden        7.3              Sweden   53208.88436
# AUT          Austria        7.2             Austria   55454.68929
# ISR           Israel        7.2              Israel   39919.16965
# AUS        Australia        7.1           Australia   51663.36509
# IRL          Ireland        7.0             Ireland   83203.39468
# CAN           Canada        7.0              Canada   48130.25597
# USA    United States        7.0       United States   62794.58565
# CZE          Czechia        6.9      Czech Republic   39743.59709
# BEL          Belgium        6.8             Belgium   51407.99834
# GBR   United Kingdom        6.8      United Kingdom   45973.57350
# FRA           France        6.7              France   45342.39574
# SVN         Slovenia        6.5            Slovenia   38048.78466
# ESP            Spain        6.5               Spain   39715.43906
# SVK  Slovak Republic        6.5     Slovak Republic   33736.40094
# EST          Estonia        6.5             Estonia   35973.77646
# ITA            Italy        6.5               Italy   41830.42633
# LTU        Lithuania        6.4           Lithuania   35461.35910
# CRI       Costa Rica        6.3          Costa Rica   17671.09535
# CHL            Chile        6.2               Chile   25222.52778
# LVA           Latvia        6.2              Latvia   30304.85250
# JPN            Japan        6.1               Japan   42797.45852
# POL           Poland        6.1              Poland   31336.60350
# BRA           Brazil        6.1              Brazil   16096.40096
# MEX           Mexico        6.0              Mexico   19844.64567
# HUN          Hungary        6.0             Hungary   31102.50275
# GRC           Greece        5.8              Greece   29592.15242
# PRT         Portugal        5.8            Portugal   33415.43790
# KOR            Korea        5.8         Korea, Rep.   40111.77576
# COL         Colombia        5.7            Colombia   15012.93027
# RUS           Russia        5.5  Russian Federation   27588.12544
# TUR          Türkiye        4.9              Turkey   28068.85941
# ZAF     South Africa        4.9        South Africa   13686.88236

# %%
df[['OBS_VALUE']].plot() # plota o gráfico
# Out:
# <Axes: >

# %%
df[['2018']].plot()
# Out:
# <Axes: >

# %%
df.plot(kind = 'scatter', x = 'OBS_VALUE', y = '2018') # scatter = disperso
# Out:
# <Axes: xlabel='OBS_VALUE', ylabel='2018'>

# %%
pd.plotting.scatter_matrix(df, figsize=(15,15)) #  Mostra gráficos de dispersão e histogramas para explorar relações entre colunas numéricas.
# Out:
# array([[<Axes: xlabel='OBS_VALUE', ylabel='OBS_VALUE'>,
#         <Axes: xlabel='2018', ylabel='OBS_VALUE'>],
#        [<Axes: xlabel='OBS_VALUE', ylabel='2018'>,
#         <Axes: xlabel='2018', ylabel='2018'>]], dtype=object)

# %% [markdown]
# #Correlation measures the relationship between two variables.
# * Values Between -1 and 1
#  * 1 = there is a perfect linear relationship between the variables
#  * 0 = there is no linear relationship between the variables
#  * -1 = there is a perfect negative linear relationship between the variables
#
# **There is an important difference between correlation and causality:**
# * Correlation is a number that measures how closely the data are related
# * Causality is the conclusion that x causes y.
#
# **Correlation Does Not Imply Causality**
#
# * During the summer, the sale of ice cream at a beach increases
# * Simultaneously, drowning accidents also increase as well
# * Does this mean that increase of ice cream sale is a direct cause of increased drowning accidents?

# %%
df[['2018', 'OBS_VALUE']].corr() # calcula matriz de correção (de -1 até 1), no caso, uns 70%. correlação linear
# Out:
#                2018  OBS_VALUE
# 2018       1.000000   0.709689
# OBS_VALUE  0.709689   1.000000

# %% [markdown]
# Com base nos valores obtidos, pode-se afirmar que existe significativa correlação entre o GDP de 2018 e os valores de BLI por país.

# %% [markdown]
# # Exercício
# Baixe a base de dados de QI por país e investigue:
# 1.   qual o QI médio a nível mundial?
# 2.   qual o QI médio por continente?
# 3.   plote o gráfico de QI por país
# 4.   existe alguma correlação aparente entre QI e BLI ou GDP, investigados nos exemplos anteriores? Use JOIN.
#
# QI - arquivo CSV:<br>
# **https://worldpopulationreview.com/country-rankings/average-iq-by-country**

# %%
df_qi = pd.read_csv('qi-médio-por-país-em-2025.csv', sep = ",")
df_qi
# Out:
#     flagCode                   country  \
# 0         CN                     China
# 1         TW                    Taiwan
# 2         HK                 Hong Kong
# 3         MO                     Macau
# 4         KR               South Korea
# ..       ...                       ...
# 192       MP  Northern Mariana Islands
# 193       LI             Liechtenstein
# 194       VG    British Virgin Islands
# 195       MH          Marshall Islands
# 196       CK              Cook Islands
#
#      CountriesByIQ_AverageIQViaInternationalIQTest_avgIQ_2024  \
# 0                                               107.19
# 1                                               107.10
# 2                                               107.06
# 3                                               106.73
# 4                                               106.43
# ..                                                 ...
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
# 196                                                NaN
#
#      CountriesByIQ_AverageIQViaLynnBecker_avgIQ_2019  \
# 0                                             104.10
# 1                                             106.47
# 2                                             105.37
# 3                                              99.82
# 4                                             102.35
# ..                                               ...
# 192                                            81.36
# 193                                           101.07
# 194                                            76.69
# 195                                            83.96
# 196                                            83.96
#
#     CountriesByIQ_LynnBeckerDataSource_testOrEstimate_2019  \
# 0                                                    T
# 1                                                    T
# 2                                                    T
# 3                                                    E
# 4                                                    T
# ..                                                 ...
# 192                                                  E
# 193                                                  E
# 194                                                  E
# 195                                                  T
# 196                                                  E
#
#     CountriesByIQ_ICI2017Score  CountriesByIQ_ICI2017Grade
# 0                            B                        47.3
# 1                            B                        45.7
# 2                           B+                        51.2
# 3                          NaN                         NaN
# 4                           A-                        56.4
# ..                         ...                         ...
# 192                        NaN                         NaN
# 193                        NaN                         NaN
# 194                        NaN                         NaN
# 195                        NaN                         NaN
# 196                        NaN                         NaN
#
# [197 rows x 7 columns]

# %%
df_qi.head()
# Out:
#   flagCode      country  \
# 0       CN        China
# 1       TW       Taiwan
# 2       HK    Hong Kong
# 3       MO        Macau
# 4       KR  South Korea
#
#    CountriesByIQ_AverageIQViaInternationalIQTest_avgIQ_2024  \
# 0                                             107.19
# 1                                             107.10
# 2                                             107.06
# 3                                             106.73
# 4                                             106.43
#
#    CountriesByIQ_AverageIQViaLynnBecker_avgIQ_2019  \
# 0                                           104.10
# 1                                           106.47
# 2                                           105.37
# 3                                            99.82
# 4                                           102.35
#
#   CountriesByIQ_LynnBeckerDataSource_testOrEstimate_2019  \
# 0                                                  T
# 1                                                  T
# 2                                                  T
# 3                                                  E
# 4                                                  T
#
#   CountriesByIQ_ICI2017Score  CountriesByIQ_ICI2017Grade
# 0                          B                        47.3
# 1                          B                        45.7
# 2                         B+                        51.2
# 3                        NaN                         NaN
# 4                         A-                        56.4

# %%
df_qi.columns
# Out:
# Index(['flagCode', 'country',
#        'CountriesByIQ_AverageIQViaInternationalIQTest_avgIQ_2024',
#        'CountriesByIQ_AverageIQViaLynnBecker_avgIQ_2019',
#        'CountriesByIQ_LynnBeckerDataSource_testOrEstimate_2019',
#        'CountriesByIQ_ICI2017Score', 'CountriesByIQ_ICI2017Grade'],
#       dtype='object')

# %%
df_qi.describe() # estatistico
# Out:
#        CountriesByIQ_AverageIQViaInternationalIQTest_avgIQ_2024  \
# count                                         129.000000
# mean                                           96.830775
# std                                             4.829378
# min                                            85.080000
# 25%                                            93.950000
# 50%                                            97.320000
# 75%                                            99.740000
# max                                           107.190000
#
#        CountriesByIQ_AverageIQViaLynnBecker_avgIQ_2019  \
# count                                       197.000000
# mean                                         82.030964
# std                                          13.410724
# min                                          42.990000
# 25%                                          74.330000
# 50%                                          83.130000
# 75%                                          91.600000
# max                                         106.480000
#
#        CountriesByIQ_ICI2017Grade
# count                  127.000000
# mean                    33.490551
# std                     16.083465
# min                      6.800000
# 25%                     22.000000
# 50%                     29.600000
# 75%                     46.050000
# max                     74.900000

# %%
df_qi.info() # estrutural
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 7 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   flagCode                                                  196 non-null    object
#  1   country                                                   197 non-null    object
#  2   CountriesByIQ_AverageIQViaInternationalIQTest_avgIQ_2024  129 non-null    float64
#  3   CountriesByIQ_AverageIQViaLynnBecker_avgIQ_2019           197 non-null    float64
#  4   CountriesByIQ_LynnBeckerDataSource_testOrEstimate_2019    197 non-null    object
#  5   CountriesByIQ_ICI2017Score                                127 non-null    object
#  6   CountriesByIQ_ICI2017Grade                                127 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 10.9+ KB

# %%
respostas = df_qi[[ # qi medio mundial
    'CountriesByIQ_AverageIQViaInternationalIQTest_avgIQ_2024',
    'CountriesByIQ_AverageIQViaLynnBecker_avgIQ_2019',
    'CountriesByIQ_LynnBeckerDataSource_testOrEstimate_2019',
    'CountriesByIQ_ICI2017Score',
    'CountriesByIQ_ICI2017Grade'
]].mean(numeric_only=True)

print(f"QI médio mundial:\n {respostas}")
# Out:
# QI médio mundial:
#  CountriesByIQ_AverageIQViaInternationalIQTest_avgIQ_2024    96.830775
# CountriesByIQ_AverageIQViaLynnBecker_avgIQ_2019             85.346744
# CountriesByIQ_ICI2017Grade                                  35.543860
# dtype: float64

# %%
df_qi.plot(kind = 'scatter', x = 'flagCode', y = 'CountriesByIQ_AverageIQViaInternationalIQTest_avgIQ_2024') # grafico plotado para cada flag code (contiente)
# Out:
# <Axes: xlabel='flagCode', ylabel='CountriesByIQ_AverageIQViaInternationalIQTest_avgIQ_2024'>

# %% [markdown]
# Existe correlação entre BLI e o QI.

# %%
df_corr_GDP = df_GDP.set_index('Country ').join(df_qi.set_index('country'), how = 'inner') # correlacao
df_corr_GDP
# Out:
#                      Country Code          2018 flagCode  \
# Angola                        AGO   6452.355165       AO
# Albania                       ALB  13364.155400       AL
# United Arab Emirates          ARE  75075.257410       AE
# Argentina                     ARG  20610.568550       AR
# Armenia                       ARM  10343.175590       AM
# ...                           ...           ...      ...
# United States                 USA  62794.585650       US
# Uzbekistan                    UZB   8556.051512       UZ
# Vietnam                       VNM   7447.814334       VN
# South Africa                  ZAF  13686.882360       ZA
# Zimbabwe                      ZWE   3029.793005       ZW
#
#                       CountriesByIQ_AverageIQViaInternationalIQTest_avgIQ_2024  \
# Angola                                                            85.33
# Albania                                                           97.19
# United Arab Emirates                                              96.80
# Argentina                                                         94.39
# Armenia                                                          102.58
# ...                                                                 ...
# United States                                                     99.74
# Uzbekistan                                                        96.79
# Vietnam                                                          100.12
# South Africa                                                      94.11
# Zimbabwe                                                          90.21
#
#                       CountriesByIQ_AverageIQViaLynnBecker_avgIQ_2019  \
# Angola                                                          75.10
# Albania                                                         81.75
# United Arab Emirates                                            82.05
# Argentina                                                       86.63
# Armenia                                                         88.82
# ...                                                               ...
# United States                                                   97.43
# Uzbekistan                                                      89.01
# Vietnam                                                         89.53
# South Africa                                                    68.87
# Zimbabwe                                                        74.01
#
#                      CountriesByIQ_LynnBeckerDataSource_testOrEstimate_2019  \
# Angola                                                                T
# Albania                                                               E
# United Arab Emirates                                                  T
# Argentina                                                             T
# Armenia                                                               E
# ...                                                                 ...
# United States                                                         T
# Uzbekistan                                                            T
# Vietnam                                                               T
# South Africa                                                          T
# Zimbabwe                                                              T
#
#                      CountriesByIQ_ICI2017Score  CountriesByIQ_ICI2017Grade
# Angola                                      NaN                         NaN
# Albania                                      D+                        23.4
# United Arab Emirates                         C+                        35.9
# Argentina                                    B-                        40.5
# Armenia                                      C-                        29.6
# ...                                         ...                         ...
# United States                                A+                        74.9
# Uzbekistan                                  NaN                         NaN
# Vietnam                                      C-                        25.1
# South Africa                                  C                        33.0
# Zimbabwe                                     D-                        11.7
#
# [112 rows x 8 columns]
